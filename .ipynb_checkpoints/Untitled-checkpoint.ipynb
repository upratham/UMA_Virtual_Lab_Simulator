# %%
from sqlalchemy import create_engine, Column, Integer, String, Enum
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# Define the database URL
DATABASE_URL = "mysql+mysqlconnector://root:Captain@56@localhost/virtual_lab_sim"

# Create the engine
engine = create_engine("mysql+mysqlconnector://root:Captain@56@localhost", echo=True)

# Create the 'virtual_lab_sim' database if it does not exist
with engine.connect() as connection:
    connection.execute("CREATE DATABASE IF NOT EXISTS virtual_lab_sim")

# Update the engine to use the 'virtual_lab_sim' database
engine = create_engine(DATABASE_URL, echo=True)

# Create a base class for declarative class definitions
Base = declarative_base()

# Define the 'users' table as a Python class
class User(Base):
    __tablename__ = 'users'

    id = Column(Integer, primary_key=True, autoincrement=True)
    username = Column(String(50), nullable=False)
    password = Column(String(255), nullable=False)
    role = Column(Enum('student', 'director'), nullable=False)

# Create the 'users' table in the 'virtual_lab_sim' database
Base.metadata.create_all(engine)

print("Database 'virtual_lab_sim' and table 'users' created successfully!")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\envs\tf\lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: NO)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\envs\tf\lib\site-packages\sqlalchemy\engine\base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\envs\tf\lib\site-packages\sqlalchemy\pool\base.py:327, in Pool.connect(self)
# ...
